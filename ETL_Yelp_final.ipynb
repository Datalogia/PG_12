# %% [markdown]
# # **ETl Yelp**

# %%
import numpy as np
import pandas as pd
import os
import seaborn as sns
import missingno as msno
import matplotlib.pyplot as plt
from datetime import datetime
import statsmodels.api as sm

# %%
df_Y2=pd.read_json(r'/content/drive/MyDrive/P_F_H/review.json',lines=True)
df_Y2.head(2)
# genera error no es posible cargar

# %%
df_Y4=pd.read_json(r'/content/drive/MyDrive/P_F_H/checkin.json',lines=True)
df_Y4.head(6)
# Archivo con datos que posiblemente no se usen
# Out:
#               business_id                                               date
# 0  ---kPU91CF4Lq2-WlRu9Lw  2020-03-13 21:10:56, 2020-06-02 22:18:06, 2020...
# 1  --0iUa4sNDFiZFrAdIWhZQ  2010-09-13 21:43:09, 2011-05-04 23:08:15, 2011...
# 2  --30_8IhuyMHbSOcNWd6DQ           2013-06-14 23:29:17, 2014-08-13 23:20:22
# 3  --7PUidqRWpRSpXebiyxTg  2011-02-15 17:12:00, 2011-07-28 02:46:10, 2012...
# 4  --7jw19RH9JKXgFohspgQw  2014-04-21 20:42:11, 2014-04-28 21:04:46, 2014...
# 5  --8IbOsAAxjKRoYsBFL-PA  2015-06-06 01:03:19, 2015-07-29 16:50:58, 2015...

# %%
df_Y4.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 131930 entries, 0 to 131929
# Data columns (total 2 columns):
#  #   Column       Non-Null Count   Dtype
# ---  ------       --------------   -----
#  0   business_id  131930 non-null  object
#  1   date         131930 non-null  object
# dtypes: object(2)
# memory usage: 2.0+ MB

# %%
# Archivo generado anteriromente ,seria usado para realizar el entrecruzamiento de los datos
df_y1=pd.read_parquet('/content/drive/MyDrive/P_F_H/user_y.parquet')
df_y1.head(2)
# Out:
#                   user_id  review_count        yelping_since  \
# 0  qVc8ODYU5SZjKXVBgXdI7w           585  2007-01-25 16:47:26
# 1  j14WgRoU_-2ZE1aw1dXrJg          4333  2009-01-25 04:35:42
#
#                                                elite  average_stars
# 0                                               2007           3.91
# 1  2009,2010,2011,2012,2013,2014,2015,2016,2017,2...           3.74

# %%
df_Y3=pd.read_json(r'/content/drive/MyDrive/P_F_H/tip.json',lines=True)
df_Y3.head(6)
# archivo a entrecruzar por id de usuario
# Out:
#                   user_id             business_id  \
# 0  AGNUgVwnZUey3gcPCJ76iw  3uLgwr0qeCNMjKenHJwPGQ
# 1  NBN4MgHP9D3cw--SnauTkA  QoezRbYQncpRqyrLH6Iqjg
# 2  -copOvldyKh1qr-vzkDEvw  MYoRNLb5chwjQe3c_k37Gg
# 3  FjMQVZjSqY8syIO-53KFKw  hV-bABTK-glh5wj31ps_Jw
# 4  ld0AperBXk1h6UbqmM80zw  _uN0OudeJ3Zl_tf6nxg5ww
# 5  trf3Qcz8qvCDKXiTgjUcEg  7Rm9Ba50bw23KTA8RedZYg
#
#                                                 text                date  \
# 0                     Avengers time with the ladies. 2012-05-18 02:17:21
# 1  They have lots of good deserts and tasty cuban... 2013-02-05 18:35:10
# 2             It's open even when you think it isn't 2013-08-18 00:56:08
# 3                          Very decent fried chicken 2017-06-27 23:05:38
# 4             Appetizers.. platter special for lunch 2012-10-06 19:43:09
# 5  Chili Cup + Single Cheeseburger with onion, pi... 2012-03-13 04:00:52
#
#    compliment_count
# 0                 0
# 1                 0
# 2                 0
# ...

# %%
df_Y3.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 908915 entries, 0 to 908914
# Data columns (total 5 columns):
#  #   Column            Non-Null Count   Dtype
# ---  ------            --------------   -----
#  0   user_id           908915 non-null  object
#  1   business_id       908915 non-null  object
#  2   text              908915 non-null  object
#  3   date              908915 non-null  datetime64[ns]
#  4   compliment_count  908915 non-null  int64
# dtypes: datetime64[ns](1), int64(1), object(3)
# memory usage: 34.7+ MB

# %%
# Realizo union de datos
dat_yelp_union=pd.merge(df_y1,df_Y3, on='user_id')
dat_yelp_union
# Out:
#                        user_id  review_count        yelping_since  \
# 0       j14WgRoU_-2ZE1aw1dXrJg          4333  2009-01-25 04:35:42
# 1       j14WgRoU_-2ZE1aw1dXrJg          4333  2009-01-25 04:35:42
# 2       j14WgRoU_-2ZE1aw1dXrJg          4333  2009-01-25 04:35:42
# 3       j14WgRoU_-2ZE1aw1dXrJg          4333  2009-01-25 04:35:42
# 4       j14WgRoU_-2ZE1aw1dXrJg          4333  2009-01-25 04:35:42
# ...                        ...           ...                  ...
# 908910  2GTi2auMvTWFxcWgTMwBYA             1  2018-02-12 16:05:54
# 908911  2GTi2auMvTWFxcWgTMwBYA             1  2018-02-12 16:05:54
# 908912  uy-cR58Bf3t7amuisRT61A             6  2016-01-08 23:38:03
# 908913  uyKAXuFGumalDTwdm3sp5g             3  2016-07-03 00:31:19
# 908914  Ea2Ik9OLTD5p9VvL_paKag             2  2014-08-24 23:43:58
#
#                                                     elite  average_stars  \
# 0       2009,2010,2011,2012,2013,2014,2015,2016,2017,2...           3.74
# ...

# %%
dat_yelp_union.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 908915 entries, 0 to 908914
# Data columns (total 9 columns):
#  #   Column            Non-Null Count   Dtype
# ---  ------            --------------   -----
#  0   user_id           908915 non-null  object
#  1   review_count      908915 non-null  int64
#  2   yelping_since     908915 non-null  object
#  3   elite             908915 non-null  object
#  4   average_stars     908915 non-null  float64
#  5   business_id       908915 non-null  object
#  6   text              908915 non-null  object
#  7   date              908915 non-null  datetime64[ns]
#  8   compliment_count  908915 non-null  int64
# dtypes: datetime64[ns](1), float64(1), int64(2), object(5)
# memory usage: 69.3+ MB

# %%
dat_yelp_union.drop(['elite','compliment_count'], axis=1,inplace=True)

# %%
dat_yelp_union.head(3)
# Out:
#                   user_id  review_count        yelping_since  average_stars  \
# 0  j14WgRoU_-2ZE1aw1dXrJg          4333  2009-01-25 04:35:42           3.74
# 1  j14WgRoU_-2ZE1aw1dXrJg          4333  2009-01-25 04:35:42           3.74
# 2  j14WgRoU_-2ZE1aw1dXrJg          4333  2009-01-25 04:35:42           3.74
#
#               business_id                                               text  \
# 0  DPtdBtLp6ng9cAB9_rzB6g  The second floor in the back of Tootsie's has ...
# 1  JVDHxMnKjif8XdXVFWiClg                       Happy hour runs 6-8pm daily.
# 2  FQ_QUyrwtnaEdxUxruZkXg    Event photos are available in a matter of days.
#
#                  date
# 0 2018-10-16 14:58:22
# 1 2019-07-20 10:20:31
# 2 2019-10-19 17:48:08

# %%
dat_yelp_union["text"]=dat_yelp_union["text"].astype('string')

# %%
dat_yelp_union["user_id"]=dat_yelp_union["user_id"].astype('string')

# %%
dat_yelp_union["business_id"]=dat_yelp_union["business_id"].astype('string')

# %%
dat_yelp_union["yelping_since"] = pd.to_datetime(dat_yelp_union["yelping_since"], format='%Y-%m-%d')
#dat_yelp_union['yelping_since'] = pd.to_datetime (dat_yelp_union['yelping_since'])

# %%
dat_yelp_union.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 908915 entries, 0 to 908914
# Data columns (total 7 columns):
#  #   Column         Non-Null Count   Dtype
# ---  ------         --------------   -----
#  0   user_id        908915 non-null  string
#  1   review_count   908915 non-null  int64
#  2   yelping_since  908915 non-null  datetime64[ns]
#  3   average_stars  908915 non-null  float64
#  4   business_id    908915 non-null  string
#  5   text           908915 non-null  string
#  6   date           908915 non-null  datetime64[ns]
# dtypes: datetime64[ns](2), float64(1), int64(1), string(3)
# memory usage: 55.5 MB

# %%
dat_yelp_union.to_parquet('user_buss_Y.parquet', index=False, compression='gzip')
