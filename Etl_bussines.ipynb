# %% [markdown]
# # **Etl archivo pkl**

# %%
import numpy as np
import pandas as pd
import os
import seaborn as sns
import missingno as msno
import matplotlib.pyplot as plt
from datetime import datetime
import statsmodels.api as sm
import  pickle

# %%
f=open('/content/drive/MyDrive/P_F_H/business.pkl','rb')
data = pickle.load(f)

# %%
print(data)
# Out:
#                    business_id                      name  \
# 0       Pns2l4eNsfO8kk83dixA6A  Abby Rappoport, LAC, CMQ
# 1       mpf3x-BjTdTEA3yCZrAYPw             The UPS Store
# 2       tUFrWirKiKi_TAnsVWINQQ                    Target
# 3       MTSW4McQd7CbVtyjqoe9mw        St Honore Pastries
# 4       mWMc6_wTdE0EUBKIGXDVfA  Perkiomen Valley Brewery
# ...                        ...                       ...
# 150341  IUQopTMmYQG-qRtBk-8QnA              Binh's Nails
# 150342  c8GjPIOTGVmIemT7j5_SyQ      Wild Birds Unlimited
# 150343  _QAMST-NrQobXduilWEqSw         Claire's Boutique
# 150344  mtGm22y5c2UHNXDFAjaPNw  Cyclery & Fitness Center
# 150345  jV_XOycEzSlTx-65W906pg                   Sic Ink
#
#                                 address           city state postal_code  \
# 0                1616 Chapala St, Ste 2  Santa Barbara   NaN       93101
# 1       87 Grasso Plaza Shopping Center         Affton   NaN       63123
# ...

# %%
df = pd.read_pickle("/content/drive/MyDrive/P_F_H/business.pkl")

# %%
df
# Out:
#                    business_id                      name  \
# 0       Pns2l4eNsfO8kk83dixA6A  Abby Rappoport, LAC, CMQ
# 1       mpf3x-BjTdTEA3yCZrAYPw             The UPS Store
# 2       tUFrWirKiKi_TAnsVWINQQ                    Target
# 3       MTSW4McQd7CbVtyjqoe9mw        St Honore Pastries
# 4       mWMc6_wTdE0EUBKIGXDVfA  Perkiomen Valley Brewery
# ...                        ...                       ...
# 150341  IUQopTMmYQG-qRtBk-8QnA              Binh's Nails
# 150342  c8GjPIOTGVmIemT7j5_SyQ      Wild Birds Unlimited
# 150343  _QAMST-NrQobXduilWEqSw         Claire's Boutique
# 150344  mtGm22y5c2UHNXDFAjaPNw  Cyclery & Fitness Center
# 150345  jV_XOycEzSlTx-65W906pg                   Sic Ink
#
#                                 address           city state postal_code  \
# 0                1616 Chapala St, Ste 2  Santa Barbara   NaN       93101
# 1       87 Grasso Plaza Shopping Center         Affton   NaN       63123
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 150346 entries, 0 to 150345
# Data columns (total 28 columns):
#  #   Column        Non-Null Count   Dtype
# ---  ------        --------------   -----
#  0   business_id   150346 non-null  object
#  1   name          150346 non-null  object
#  2   address       150346 non-null  object
#  3   city          150346 non-null  object
#  4   state         150343 non-null  object
#  5   postal_code   150346 non-null  object
#  6   latitude      150346 non-null  object
#  7   longitude     150346 non-null  object
#  8   stars         150346 non-null  object
#  9   review_count  150346 non-null  object
#  10  is_open       150346 non-null  object
#  11  attributes    136602 non-null  object
#  12  categories    150243 non-null  object
#  13  hours         127123 non-null  object
#  14  business_id   5 non-null       object
#  15  name          5 non-null       object
#  16  address       5 non-null       object
# ...

# %%
df.isnull().sum()
# Out:
# business_id          0
# name                 0
# address              0
# city                 0
# state                3
# postal_code          0
# latitude             0
# longitude            0
# stars                0
# review_count         0
# is_open              0
# attributes       13744
# categories         103
# hours            23223
# business_id     150341
# name            150341
# address         150341
# city            150341
# state           150341
# postal_code     150341
# latitude        150341
# longitude       150341
# stars           150341
# review_count    150341
# is_open         150341
# attributes      150341
# categories      150341
# hours           150341
# dtype: int64

# %%
#df.dropna(subset=['state'],inplace=True)

# %%
df.isnull().sum()
# Out:
# business_id     0
# name            0
# address         0
# city            0
# state           0
# postal_code     0
# latitude        0
# longitude       0
# stars           0
# review_count    0
# is_open         0
# attributes      0
# categories      0
# hours           0
# business_id     0
# name            0
# address         0
# city            0
# state           0
# postal_code     0
# latitude        0
# longitude       0
# stars           0
# review_count    0
# is_open         0
# attributes      0
# categories      0
# hours           0
# dtype: int64

# %%
df.iloc[:,27].info()
# Out:
# <class 'pandas.core.series.Series'>
# Int64Index: 150346 entries, 0 to 150345
# Series name: hours
# Non-Null Count  Dtype
# --------------  -----
# 5 non-null      object
# dtypes: object(1)
# memory usage: 2.3+ MB

# %%
# Seccion a cortar ya que al parecer el archivo pkl tiene columnas agregadas
# de mas por eso se extraen  las filas de esas columnas con datos son solo 5 filas
rec=df[df.iloc[:,27].isnull()==False].copy()
rec
# Out:
#                  business_id       name                             address  \
# 590   6_Zf2QsRHCH1RhbzA9inyw  Starbucks               8602 Hillsborough Ave
# 613   Iipfa9Kaac9XH5Vo8GQwvg  Starbucks                     5956 153 Avenue
# 978   oY6osC4Ch3PvguA7D1hh_w  Starbucks                    1251 Route 130 S
# 1296  pxuMxh5oC7W-PDN9wwvozg  Starbucks                     219 N Center St
# 1543  lo2VbA7Lwzu3i23pQpmzlw  Starbucks  1125 S Black Horse Pike, Space 575
#
#                      city state postal_code   latitude   longitude stars  \
# 590                 Tampa    LA       33615   27.99637  -82.580954   3.0
# 613              Edmonton    PA     T5Y 2W1  53.616147 -113.432424   3.5
# 978           Cinnaminson    AZ       08077  40.000157  -74.987313   4.5
# 1296                 Reno    FL       89501  39.527772 -119.812518   3.0
# 1543  Gloucester Township    NJ       08012   39.78403   -75.05207   3.0
#
# ...

# %%
copia=rec.iloc[:,14:27].copy()
copia
# Out:
#                  business_id       name                             address  \
# 590   6_Zf2QsRHCH1RhbzA9inyw  STarbucks               8602 Hillsborough Ave
# 613   Iipfa9Kaac9XH5Vo8GQwvg  STarbucks                     5956 153 Avenue
# 978   oY6osC4Ch3PvguA7D1hh_w  STarbucks                    1251 Route 130 S
# 1296  pxuMxh5oC7W-PDN9wwvozg  STarbucks                     219 N Center St
# 1543  lo2VbA7Lwzu3i23pQpmzlw  STarbucks  1125 S Black Horse Pike, Space 575
#
#                      city state postal_code   latitude   longitude stars  \
# 590                 Tampa    LA       33615   27.99637  -82.580954   3.0
# 613              Edmonton    PA     T5Y 2W1  53.616147 -113.432424   3.5
# 978           Cinnaminson    AZ       08077  40.000157  -74.987313   4.5
# 1296                 Reno    FL       89501  39.527772 -119.812518   3.0
# 1543  Gloucester Township    NJ       08012   39.78403   -75.05207   3.0
#
# ...

# %%
df.columns[14:27]
# Out:
# Index(['business_id', 'name', 'address', 'city', 'state', 'postal_code',
#        'latitude', 'longitude', 'stars', 'review_count', 'is_open',
#        'attributes', 'categories'],
#       dtype='object')

# %%
df3=df.copy()

# %%
#df = df.drop(df.columns[[14, 23]], axis='columns',inplace=True)
#df2.drop(df2.columns[[14,23]], axis='columns',inplace=True)
#df2.drop(df2.columns[14], axis=1,inplace=True)
print(df3[df3['state']=='NJ'])
# Out:
# <ipython-input-13-8d508555165b>:4: FutureWarning: reindexing with a non-unique Index is deprecated and will raise in a future version.
#   print(df3[df3['state']=='NJ'])
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-13-8d508555165b> in <cell line: 4>()
#       2 #df2.drop(df2.columns[[14,23]], axis='columns',inplace=True)
#       3 #df2.drop(df2.columns[14], axis=1,inplace=True)
# ----> 4 print(df3[df3['state']=='NJ'])
#
# /usr/local/lib/python3.10/dist-packages/pandas/core/frame.py in __getitem__(self, key)
#    3792         # Do we have a (boolean) DataFrame?
#    3793         if isinstance(key, DataFrame):
# -> 3794             return self.where(key)
#    3795
#    3796         # Do we have a (boolean) 1d indexer?
#
# /usr/local/lib/python3.10/dist-packages/pandas/util/_decorators.py in wrapper(*args, **kwargs)
#     209                 else:
# ...

# %%
df3.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 150346 entries, 0 to 150345
# Data columns (total 28 columns):
#  #   Column        Non-Null Count   Dtype
# ---  ------        --------------   -----
#  0   business_id   150346 non-null  object
#  1   name          150346 non-null  object
#  2   address       150346 non-null  object
#  3   city          150346 non-null  object
#  4   state         150343 non-null  object
#  5   postal_code   150346 non-null  object
#  6   latitude      150346 non-null  object
#  7   longitude     150346 non-null  object
#  8   stars         150346 non-null  object
#  9   review_count  150346 non-null  object
#  10  is_open       150346 non-null  object
#  11  attributes    136602 non-null  object
#  12  categories    150243 non-null  object
#  13  hours         127123 non-null  object
#  14  business_id   5 non-null       object
#  15  name          5 non-null       object
#  16  address       5 non-null       object
# ...

# %%
df3.head(3)
# Out:
#               business_id                      name  \
# 0  Pns2l4eNsfO8kk83dixA6A  Abby Rappoport, LAC, CMQ
# 1  mpf3x-BjTdTEA3yCZrAYPw             The UPS Store
# 2  tUFrWirKiKi_TAnsVWINQQ                    Target
#
#                            address           city state postal_code  \
# 0           1616 Chapala St, Ste 2  Santa Barbara   NaN       93101
# 1  87 Grasso Plaza Shopping Center         Affton   NaN       63123
# 2             5255 E Broadway Blvd         Tucson   NaN       85711
#
#     latitude   longitude stars review_count  ... state postal_code latitude  \
# 0  34.426679 -119.711197   5.0            7  ...   NaN         NaN      NaN
# 1  38.551126  -90.335695   3.0           15  ...   NaN         NaN      NaN
# 2  32.223236 -110.880452   3.5           22  ...   NaN         NaN      NaN
#
#   longitude stars review_count is_open attributes categories hours
# 0       NaN   NaN          NaN     NaN        NaN        NaN   NaN
# ...

# %%
df.drop(['elite','compliment_count'], axis=1,inplace=True)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-12-7801921f29cb> in <cell line: 1>()
# ----> 1 dat_yelp_union.drop(['elite','compliment_count'], axis=1,inplace=True)
#
# NameError: name 'dat_yelp_union' is not defined

# %%
 df.to_csv("example.csv", index=False)
