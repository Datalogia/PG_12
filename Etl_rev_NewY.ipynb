# %%
import numpy as np
import pandas as pd
import os
import seaborn as sns
import missingno as msno
import matplotlib.pyplot as plt
from datetime import datetime
import statsmodels.api as sm

# %%
df_rev2=pd.read_json(r'/content/drive/MyDrive/P_F_H/2.json',lines=True)
df_rev2.head(2)
# Out:
#         user_id            name           time  rating  \
# 0  1.127472e+20  Benjamin Vidot  1560405775843       5
# 1  1.048890e+20       Joel Bing  1558663754858       4
#
#                                                 text  pics  resp  \
# 0  Hot and cold sandwich's cold sodas and much mo...  None  None
# 1                    Nice environment cozy good food  None  None
#
#                                  gmap_id
# 0  0x89c2f48ae322c115:0xd28226c7ffc52291
# 1  0x89c2f48ae322c115:0xd28226c7ffc52291

# %%
df_rev3=pd.read_json(r'/content/drive/MyDrive/P_F_H/3.json',lines=True)
df_rev3.head(2)
# Out:
#         user_id            name           time  rating  \
# 0  1.121598e+20     Kevin Noble  1531531850612       4
# 1  1.120503e+20  Joseph Hanover  1471217722578       4
#
#                                                 text  pics  resp  \
# 0  Large electrical wholesaler with very good sto...  None  None
# 1  Good service and they know what those talking ...  None  None
#
#                                  gmap_id
# 0  0x89d9f3c896fd648f:0x26e65f259859802f
# 1  0x89d9f3c896fd648f:0x26e65f259859802f

# %%
df_rev4=pd.read_json(r'/content/drive/MyDrive/P_F_H/4.json',lines=True)
df_rev4.head(2)
# Out:
#         user_id           name           time  rating                    text  \
# 0  1.121496e+20  Annette Green  1570882095310       4  The food  is excellent
# 1  1.027794e+20  Yonette Hinds  1552593653693       5     Great tasting food.
#
#    pics  resp                                gmap_id
# 0  None  None  0x89c25b60682deed3:0x3e007cd09ec0f0e5
# 1  None  None  0x89c25b60682deed3:0x3e007cd09ec0f0e5

# %%
df_rev5=pd.read_json(r'/content/drive/MyDrive/P_F_H/5.json',lines=True)
df_rev5.head(2)
# Out:
#         user_id      name           time  rating  \
# 0  1.120959e+20  Sharyn R  1618536541236       5
# 1  1.003088e+20  gcas8609  1612889799718       1
#
#                                                 text  pics  resp  \
# 0              Awesome Food 😄😁 Chill and cool staff.  None  None
# 1  The Most DISGUSTING food I've had in my whole ...  None  None
#
#                                  gmap_id
# 0  0x89c25daf13bc726b:0x7f609addad46f073
# 1  0x89c25daf13bc726b:0x7f609addad46f073

# %%
df_rev6=pd.read_json(r'/content/drive/MyDrive/P_F_H/6.json',lines=True)
df_rev6.head(2)
# Out:
#         user_id                 name           time  rating  \
# 0  1.110427e+20  richard clinkscales  1554254215610       5
# 1  1.030982e+20     Doris Vignapiano  1525028535766       5
#
#                                                 text  pics  resp  \
# 0  Really good uv gel polish and fast service wif...  None  None
# 1  My go-to for nails with my daughter. We love i...  None  None
#
#                                  gmap_id
# 0  0x89c24f8abea01a3d:0xd384fb4e9f6e7a84
# 1  0x89c24f8abea01a3d:0xd384fb4e9f6e7a84

# %%
df_rev7=pd.read_json(r'/content/drive/MyDrive/P_F_H/7.json',lines=True)
df_rev7.head(2)
# Out:
#         user_id           name           time  rating  text  pics  resp  \
# 0  1.080651e+20  Patrick Fagan  1542649150332       4  None  None  None
# 1  1.014358e+20  Keith Dickens  1577929127246       4  None  None  None
#
#                                  gmap_id
# 0  0x89c25a1b774ee1f7:0x2a191353784cccaa
# 1  0x89c25a1b774ee1f7:0x2a191353784cccaa

# %%
df_rev8=pd.read_json(r'/content/drive/MyDrive/P_F_H/8.json',lines=True)
df_rev8.head(2)
# Out:
#         user_id            name           time  rating                 text  \
# 0  1.128958e+20  Keicha Passley  1527367584140       5              Awesome
# 1  1.092202e+20         Md Asif  1448019745119       2  Need more stuffs...
#
#    pics  resp                                gmap_id
# 0  None  None  0x89c25d0e4e7c3bbb:0x253e2e5bf0f1e793
# 1  None  None  0x89c25d0e4e7c3bbb:0x253e2e5bf0f1e793

# %%
df_rev9=pd.read_json(r'/content/drive/MyDrive/P_F_H/9.json',lines=True)
df_rev9.head(2)
# Out:
#         user_id          name           time  rating  \
# 0  1.131217e+20  Eward Berrio  1527266837569       4
# 1  1.181466e+20     Ahmad Job  1557701021123       5
#
#                                            text  \
# 0  had a awesome time good vibes music was good
# 1                             Best time always.
#
#                                                 pics  resp  \
# 0                                               None  None
# 1  [{'url': ['https://lh5.googleusercontent.com/p...  None
#
#                                 gmap_id
# 0  0x89c2f61372562761:0xb4d169314845b83
# 1  0x89c2f61372562761:0xb4d169314845b83

# %%
df_rev10=pd.read_json(r'/content/drive/MyDrive/P_F_H/10.json',lines=True)
df_rev10.head(2)
# Out:
#         user_id             name           time  rating  text  pics  resp  \
# 0  1.136686e+20  Vanessa Montoya  1548800992937       5  None  None  None
# 1  1.027760e+20    Steven Gibson  1598496716280       4  None  None  None
#
#                                  gmap_id
# 0  0x89de0b8a0905153d:0x976fc4a006084f03
# 1  0x89de0b8a0905153d:0x976fc4a006084f03

# %%
df_rev11=pd.read_json(r'/content/drive/MyDrive/P_F_H/11.json',lines=True)
df_rev11.head(2)
# Out:
#         user_id             name           time  rating  \
# 0  1.129494e+20      Sean Bailey  1522976191648       3
# 1  1.048765e+20  Rebekah Martino  1498137899161       4
#
#                                                 text  pics  resp  \
# 0  Seems to be going downhill, employees rude and...  None  None
# 1                  Great prices, produce can be iffy  None  None
#
#                                  gmap_id
# 0  0x89de09b4a8485433:0xc87e593123ea4c9a
# 1  0x89de09b4a8485433:0xc87e593123ea4c9a

# %%
df_rev12=pd.read_json(r'/content/drive/MyDrive/P_F_H/12.json',lines=True)
df_rev12.head(2)
# Out:
#         user_id             name           time  rating  text  pics  resp  \
# 0  1.148157e+20  Jeanette Briggs  1541736113282       5  None  None  None
# 1  1.146045e+20     Shawnna Hall  1555619508383       4  None  None  None
#
#                                  gmap_id
# 0  0x89d98c47abf26edd:0x9966f6a545f71e01
# 1  0x89d98c47abf26edd:0x9966f6a545f71e01

# %%
df_rev13=pd.read_json(r'/content/drive/MyDrive/P_F_H/13.json',lines=True)
df_rev13.head(2)
# Out:
#         user_id            name           time  rating  \
# 0  1.077481e+20  Shelton Burton  1621264496040       5
# 1  1.016171e+20  hardcandy andy  1609476710150       5
#
#                                                 text  pics  resp  \
# 0                                      Great service  None  None
# 1  I haven't had any issues with the dispatchers ...  None  None
#
#                                  gmap_id
# 0  0x89c2f46bf4b24937:0xbf4874dd0a1625d5
# 1  0x89c2f46bf4b24937:0xbf4874dd0a1625d5

# %%
df_rev14=pd.read_json(r'/content/drive/MyDrive/P_F_H/14.json',lines=True)
df_rev14.head(2)
# Out:
#         user_id               name           time  rating  \
# 0  1.063855e+20                B G  1569612965056       1
# 1  1.086683e+20  Leroy Williams Jr  1580766971302       5
#
#                                                 text  pics  resp  \
# 0  One of the worst chinese restaurants I've ever...  None  None
# 1                         Love this shrimp dumplings  None  None
#
#                                  gmap_id
# 0  0x89c2f354e189accb:0x31f39ed47bc793bd
# 1  0x89c2f354e189accb:0x31f39ed47bc793bd

# %%
df_rev15=pd.read_json(r'/content/drive/MyDrive/P_F_H/15.json',lines=True)
df_rev15.head(2)
# Out:
#         user_id              name           time  rating  \
# 0  1.127843e+20    Elio Gordische  1501866677829       5
# 1  1.008193e+20  Gabriel Irizarry  1536074481409       5
#
#                                        text  pics  resp  \
# 0     Nice place to purchase your  new  car  None  None
# 1  vehicle service promptly and efficiently  None  None
#
#                                  gmap_id
# 0  0x89c2f29c3bbedc31:0xc9b6b30c5182c74f
# 1  0x89c2f29c3bbedc31:0xc9b6b30c5182c74f

# %%
df_rev16=pd.read_json(r'/content/drive/MyDrive/P_F_H/16.json',lines=True)
df_rev16.head(2)
# Out:
#         user_id               name           time  rating  text  pics  resp  \
# 0  1.175809e+20  Pops Restorations  1619195723894       4  None  None  None
# 1  1.024264e+20  Nauvella La Croix  1568741297170       4  None  None  None
#
#                                  gmap_id
# 0  0x89e832f506582463:0x30a376ff76468565
# 1  0x89e832f506582463:0x30a376ff76468565

# %%
df_rev17=pd.read_json(r'/content/drive/MyDrive/P_F_H/17.json',lines=True)
df_rev17.head(2)
# Out:
#         user_id                   name           time  rating  \
# 0  1.108201e+20  Polander613 Trains613  1563282654589       4
# 1  1.071930e+20          Pete Ragonese  1563877187487       5
#
#                                    text  pics  resp  \
# 0  Very nice, Beautiful place to visit.  None  None
# 1                       My happy place!  None  None
#
#                                  gmap_id
# 0  0x89d8b5532bbcb36d:0xc974c52315679cea
# 1  0x89d8b5532bbcb36d:0xc974c52315679cea

# %%
df_rev18=pd.read_json(r'/content/drive/MyDrive/P_F_H/18.json',lines=True)
df_rev18.head(2)
# Out:
#         user_id               name           time  rating  \
# 0  1.066702e+20  Edward McLaughlin  1618704999688       5
# 1  1.175069e+20            Guy Guy  1604187022627       5
#
#                                                 text  pics  \
# 0                Loved it food and service excellent  None
# 1  Amazing, food is always perfect, Staff is frie...  None
#
#                                                 resp  \
# 0  {'time': 1618898949777, 'text': 'Really apprec...
# 1  {'time': 1604354784066, 'text': 'Guy, I couldn...
#
#                                  gmap_id
# 0  0x89c3290c158ff89d:0x10dee88b82d7aa42
# 1  0x89c3290c158ff89d:0x10dee88b82d7aa42

# %% [markdown]
# ## Se analiza la informacion de las reviews sin perder datos al principio para luego analizarlos

# %%
data_rev=pd.concat([df_rev2,df_rev3,df_rev4,df_rev5,df_rev6,df_rev7,df_rev8,df_rev9,df_rev10,df_rev11,df_rev12,df_rev13,df_rev14,df_rev15,df_rev16,df_rev17,df_rev18],sort=False)

# %%
data_rev.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 2550000 entries, 0 to 149999
# Data columns (total 8 columns):
#  #   Column   Dtype
# ---  ------   -----
#  0   user_id  float64
#  1   name     object
#  2   time     int64
#  3   rating   int64
#  4   text     object
#  5   pics     object
#  6   resp     object
#  7   gmap_id  object
# dtypes: float64(1), int64(2), object(5)
# memory usage: 175.1+ MB

# %%
data_rev.reset_index(inplace=True, drop=True)
data_rev
# Out:
#               user_id               name           time  rating  \
# 0        1.127472e+20     Benjamin Vidot  1560405775843       5
# 1        1.048890e+20          Joel Bing  1558663754858       4
# 2        1.063806e+20        Danny Ramos  1558467764714       5
# 3        1.169573e+20     TRACY MITCHELL  1556481687751       3
# 4        1.084914e+20     Geovanni Rojas  1453077455490       1
# ...               ...                ...            ...     ...
# 2549995  1.009480e+20         Dave Kelly  1548554625702       5
# 2549996  1.175674e+20   Pearl Ciccolella  1609802212706       2
# 2549997  1.097157e+20  Cassandra Gardner  1508956653077       5
# 2549998  1.080803e+20       Kenneth Ross  1567833973049       2
# 2549999  1.087272e+20    Michael Zelonka  1534707343085       4
#
#                                                       text  pics  resp  \
# 0        Hot and cold sandwich's cold sodas and much mo...  None  None
# 1                          Nice environment cozy good food  None  None
# 2                                                Not good.  None  None
# 3                                                   Decent  None  None
# 4        (Translated by Google) Very unfortunate the ra...  None  None
# ...                                                    ...   ...   ...
# 2549995                                               None  None  None
# 2549996                                               None  None  None
# 2549997                                               None  None  None
# 2549998                                               None  None  None
# 2549999                                               None  None  None
#
#                                        gmap_id
# 0        0x89c2f48ae322c115:0xd28226c7ffc52291
# 1        0x89c2f48ae322c115:0xd28226c7ffc52291
# 2        0x89c2f48ae322c115:0xd28226c7ffc52291
# 3        0x89c2f48ae322c115:0xd28226c7ffc52291
# 4        0x89c2f48ae322c115:0xd28226c7ffc52291
# ...                                        ...
# 2549995  0x89de0e2abec2ff27:0x773f2e9ce87e1b3f
# 2549996  0x89de0e2abec2ff27:0x773f2e9ce87e1b3f
# 2549997  0x89de0e2abec2ff27:0x773f2e9ce87e1b3f
# 2549998  0x89de0e2abec2ff27:0x773f2e9ce87e1b3f
# 2549999  0x89de0e2abec2ff27:0x773f2e9ce87e1b3f
#
# [2550000 rows x 8 columns]

# %%
data_rev.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2550000 entries, 0 to 2549999
# Data columns (total 8 columns):
#  #   Column   Dtype
# ---  ------   -----
#  0   user_id  float64
#  1   name     object
#  2   time     int64
#  3   rating   int64
#  4   text     object
#  5   pics     object
#  6   resp     object
#  7   gmap_id  object
# dtypes: float64(1), int64(2), object(5)
# memory usage: 155.6+ MB

# %% [markdown]
# ##Busqueda de valores nulos

# %%
data_rev.isnull().sum()
# Out:
# user_id          0
# name             0
# time             0
# rating           0
# text       1100917
# pics       2452940
# resp       2302841
# gmap_id          0
# dtype: int64

# %%
data_rev.drop(['pics'], axis=1,inplace=True)

# %%
data_rev.drop(['name'], axis=1,inplace=True)

# %%
data_rev.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2550000 entries, 0 to 2549999
# Data columns (total 6 columns):
#  #   Column   Dtype
# ---  ------   -----
#  0   user_id  float64
#  1   time     int64
#  2   rating   int64
#  3   text     object
#  4   resp     object
#  5   gmap_id  object
# dtypes: float64(1), int64(2), object(3)
# memory usage: 116.7+ MB

# %%
# Visualizo los valores faltantes o nulos
sns.heatmap(data_rev.isnull(), cbar=False)
# Se puede ver que no hubo respuestas por parte de los locales a las reviews de usuarios
# Out:
# <Axes: >

# %%
data_rev["text"]=data_rev["text"].astype('string')
data_rev.text.info()
# Out:
# <class 'pandas.core.series.Series'>
# RangeIndex: 2550000 entries, 0 to 2549999
# Series name: text
# Non-Null Count    Dtype
# --------------    -----
# 1449083 non-null  string
# dtypes: string(1)
# memory usage: 19.5 MB

# %%
data_rev["resp"]=data_rev["resp"].astype('string')
data_rev.resp.info()
# Out:
# <class 'pandas.core.series.Series'>
# RangeIndex: 2550000 entries, 0 to 2549999
# Series name: resp
# Non-Null Count   Dtype
# --------------   -----
# 247159 non-null  string
# dtypes: string(1)
# memory usage: 19.5 MB

# %%
data_rev["gmap_id"]=data_rev["gmap_id"].astype('string')
data_rev.gmap_id.info()
# Out:
# <class 'pandas.core.series.Series'>
# RangeIndex: 2550000 entries, 0 to 2549999
# Series name: gmap_id
# Non-Null Count    Dtype
# --------------    -----
# 2550000 non-null  string
# dtypes: string(1)
# memory usage: 19.5 MB

# %%
data_rev.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2550000 entries, 0 to 2549999
# Data columns (total 6 columns):
#  #   Column   Dtype
# ---  ------   -----
#  0   user_id  float64
#  1   time     int64
#  2   rating   int64
#  3   text     string
#  4   resp     string
#  5   gmap_id  string
# dtypes: float64(1), int64(2), string(3)
# memory usage: 116.7 MB

# %%
data_rev.text.fillna('', inplace=True)

# %%
data_rev.resp.fillna('', inplace=True)

# %%
data_rev[:500000].info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 500000 entries, 0 to 499999
# Data columns (total 6 columns):
#  #   Column   Non-Null Count   Dtype
# ---  ------   --------------   -----
#  0   user_id  500000 non-null  float64
#  1   time     500000 non-null  int64
#  2   rating   500000 non-null  int64
#  3   text     500000 non-null  string
#  4   resp     500000 non-null  string
#  5   gmap_id  500000 non-null  string
# dtypes: float64(1), int64(2), string(3)
# memory usage: 22.9 MB

# %%
data_rev[:400000].to_excel('dat_rev1.xlsx',index=False,encoding='utf-8')
# Out:
# ---------------------------------------------------------------------------
# IllegalCharacterError                     Traceback (most recent call last)
# <ipython-input-97-ea66e3d54a1b> in <cell line: 1>()
# ----> 1 data_rev[:400000].to_excel('dat_rev1.xlsx',index=False,encoding='utf-8')
#
# /usr/local/lib/python3.10/dist-packages/pandas/util/_decorators.py in wrapper(*args, **kwargs)
#     209                 else:
#     210                     kwargs[new_arg_name] = new_arg_value
# --> 211             return func(*args, **kwargs)
#     212
#     213         return cast(F, wrapper)
#
# /usr/local/lib/python3.10/dist-packages/pandas/util/_decorators.py in wrapper(*args, **kwargs)
#     181                     warnings.warn(msg, FutureWarning, stacklevel=stacklevel)
#     182                     kwargs[old_arg_name] = old_arg_value
# --> 183                     return func(*args, **kwargs)
#     184
#     185                 elif mapping is not None:
#
# /usr/local/lib/python3.10/dist-packages/pandas/core/generic.py in to_excel(self, excel_writer, sheet_name, na_rep, float_format, columns, header, index, index_label, startrow, startcol, engine, merge_cells, encoding, inf_rep, verbose, freeze_panes, storage_options)
#    2372             inf_rep=inf_rep,
#    2373         )
# -> 2374         formatter.write(
#    2375             excel_writer,
#    2376             sheet_name=sheet_name,
#
# /usr/local/lib/python3.10/dist-packages/pandas/io/formats/excel.py in write(self, writer, sheet_name, startrow, startcol, freeze_panes, engine, storage_options)
#     948
#     949         try:
# --> 950             writer._write_cells(
#     951                 formatted_cells,
#     952                 sheet_name,
#
# /usr/local/lib/python3.10/dist-packages/pandas/io/excel/_openpyxl.py in _write_cells(self, cells, sheet_name, startrow, startcol, freeze_panes)
#     494                 row=startrow + cell.row + 1, column=startcol + cell.col + 1
#     495             )
# --> 496             xcell.value, fmt = self._value_with_fmt(cell.val)
#     497             if fmt:
#     498                 xcell.number_format = fmt
#
# /usr/local/lib/python3.10/dist-packages/openpyxl/cell/cell.py in value(self, value)
#     213     def value(self, value):
#     214         """Set the value and infer type and display options."""
# --> 215         self._bind_value(value)
#     216
#     217     @property
#
# /usr/local/lib/python3.10/dist-packages/openpyxl/cell/cell.py in _bind_value(self, value)
#     192
#     193         elif dt == "s":
# --> 194             value = self.check_string(value)
#     195             if len(value) > 1 and value.startswith("="):
#     196                 self.data_type = 'f'
#
# /usr/local/lib/python3.10/dist-packages/openpyxl/cell/cell.py in check_string(self, value)
#     160         value = value[:32767]
#     161         if next(ILLEGAL_CHARACTERS_RE.finditer(value), None):
# --> 162             raise IllegalCharacterError
#     163         return value
#     164
#
# IllegalCharacterError:

# %%
data_rev.loc[32767]
# Out:
# user_id                  106270738770159812608.0
# time                               1571591849690
# rating                                         5
# text
# resp
# gmap_id    0x89c25fc781099b25:0xb34cd71f4e939bce
# Name: 32767, dtype: object

# %%
data_rev.to_csv('dat_rev.csv')
# Out:
# ---------------------------------------------------------------------------
# Error                                     Traceback (most recent call last)
# <ipython-input-90-5ccb7eb60a26> in <cell line: 1>()
# ----> 1 data_rev.to_csv('dat_rev.csv', sep=',')
#
# /usr/local/lib/python3.10/dist-packages/pandas/util/_decorators.py in wrapper(*args, **kwargs)
#     209                 else:
#     210                     kwargs[new_arg_name] = new_arg_value
# --> 211             return func(*args, **kwargs)
#     212
#     213         return cast(F, wrapper)
#
# /usr/local/lib/python3.10/dist-packages/pandas/core/generic.py in to_csv(self, path_or_buf, sep, na_rep, float_format, columns, header, index, index_label, mode, encoding, compression, quoting, quotechar, lineterminator, chunksize, date_format, doublequote, escapechar, decimal, errors, storage_options)
#    3718         )
#    3719
# -> 3720         return DataFrameRenderer(formatter).to_csv(
#    3721             path_or_buf,
#    3722             lineterminator=lineterminator,
#
# /usr/local/lib/python3.10/dist-packages/pandas/util/_decorators.py in wrapper(*args, **kwargs)
#     209                 else:
#     210                     kwargs[new_arg_name] = new_arg_value
# --> 211             return func(*args, **kwargs)
#     212
#     213         return cast(F, wrapper)
#
# /usr/local/lib/python3.10/dist-packages/pandas/io/formats/format.py in to_csv(self, path_or_buf, encoding, sep, columns, index_label, mode, compression, quoting, quotechar, lineterminator, chunksize, date_format, doublequote, escapechar, errors, storage_options)
#    1187             formatter=self.fmt,
#    1188         )
# -> 1189         csv_formatter.save()
#    1190
#    1191         if created_buffer:
#
# /usr/local/lib/python3.10/dist-packages/pandas/io/formats/csvs.py in save(self)
#     259             )
#     260
# --> 261             self._save()
#     262
#     263     def _save(self) -> None:
#
# /usr/local/lib/python3.10/dist-packages/pandas/io/formats/csvs.py in _save(self)
#     264         if self._need_to_save_header:
#     265             self._save_header()
# --> 266         self._save_body()
#     267
#     268     def _save_header(self) -> None:
#
# /usr/local/lib/python3.10/dist-packages/pandas/io/formats/csvs.py in _save_body(self)
#     302             if start_i >= end_i:
#     303                 break
# --> 304             self._save_chunk(start_i, end_i)
#     305
#     306     def _save_chunk(self, start_i: int, end_i: int) -> None:
#
# /usr/local/lib/python3.10/dist-packages/pandas/io/formats/csvs.py in _save_chunk(self, start_i, end_i)
#     313
#     314         ix = self.data_index[slicer]._format_native_types(**self._number_format)
# --> 315         libwriters.write_csv_rows(
#     316             data,
#     317             ix,
#
# /usr/local/lib/python3.10/dist-packages/pandas/_libs/writers.pyx in pandas._libs.writers.write_csv_rows()
#
# Error: need to escape, but no escapechar set

# %%
data_rev.duplicated()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-38-a50d66e0df76> in <cell line: 1>()
# ----> 1 data_rev.duplicated()
#
# /usr/local/lib/python3.10/dist-packages/pandas/core/frame.py in duplicated(self, subset, keep)
#    6812         else:
#    6813             vals = (col.values for name, col in self.items() if name in subset)
# -> 6814             labels, shape = map(list, zip(*map(f, vals)))
#    6815
#    6816             ids = get_group_index(
#
# /usr/local/lib/python3.10/dist-packages/pandas/core/frame.py in f(vals)
#    6780
#    6781         def f(vals) -> tuple[np.ndarray, int]:
# -> 6782             labels, shape = algorithms.factorize(vals, size_hint=len(self))
#    6783             return labels.astype("i8", copy=False), len(shape)
#    6784
#
# /usr/local/lib/python3.10/dist-packages/pandas/core/algorithms.py in factorize(values, sort, na_sentinel, use_na_sentinel, size_hint)
#     820                 values = np.where(null_mask, na_value, values)
#     821
# --> 822         codes, uniques = factorize_array(
#     823             values,
#     824             na_sentinel=na_sentinel_arg,
#
# /usr/local/lib/python3.10/dist-packages/pandas/core/algorithms.py in factorize_array(values, na_sentinel, size_hint, na_value, mask)
#     576
#     577     table = hash_klass(size_hint or len(values))
# --> 578     uniques, codes = table.factorize(
#     579         values,
#     580         na_sentinel=na_sentinel,
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.factorize()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable._unique()
#
# TypeError: unhashable type: 'dict'

# %%
data_rev = data_rev[data_rev.duplicated()]
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-33-58210c46a297> in <cell line: 1>()
# ----> 1 data_rev = data_rev[data_rev.duplicated()]
#
# /usr/local/lib/python3.10/dist-packages/pandas/core/frame.py in duplicated(self, subset, keep)
#    6812         else:
#    6813             vals = (col.values for name, col in self.items() if name in subset)
# -> 6814             labels, shape = map(list, zip(*map(f, vals)))
#    6815
#    6816             ids = get_group_index(
#
# /usr/local/lib/python3.10/dist-packages/pandas/core/frame.py in f(vals)
#    6780
#    6781         def f(vals) -> tuple[np.ndarray, int]:
# -> 6782             labels, shape = algorithms.factorize(vals, size_hint=len(self))
#    6783             return labels.astype("i8", copy=False), len(shape)
#    6784
#
# /usr/local/lib/python3.10/dist-packages/pandas/core/algorithms.py in factorize(values, sort, na_sentinel, use_na_sentinel, size_hint)
#     820                 values = np.where(null_mask, na_value, values)
#     821
# --> 822         codes, uniques = factorize_array(
#     823             values,
#     824             na_sentinel=na_sentinel_arg,
#
# /usr/local/lib/python3.10/dist-packages/pandas/core/algorithms.py in factorize_array(values, na_sentinel, size_hint, na_value, mask)
#     576
#     577     table = hash_klass(size_hint or len(values))
# --> 578     uniques, codes = table.factorize(
#     579         values,
#     580         na_sentinel=na_sentinel,
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.factorize()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable._unique()
#
# TypeError: unhashable type: 'list'
